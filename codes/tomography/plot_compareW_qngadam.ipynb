# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
path = "../../experiments/tomography_wchain_2/4/fidelities_qng_adam.csv"
fidelities1 = pd.read_csv(path, sep=",", header=None)
fidelities1 = fidelities1.applymap(lambda s: complex(s.replace('i', 'j'))).values
path = "../../experiments/tomography_wchain_2/4/traces_qng_adam.csv"
traces1 = pd.read_csv(path, sep=",", header=None)
path = "../../experiments/tomography_wchain_2/4/loss_values_qng_adam.csv"
loss_values1 = pd.read_csv(path, sep=",", header=None)
path = "../../experiments/tomography_walltoall_2/4/fidelities_qng_adam.csv"
fidelities2 = pd.read_csv(path, sep=",", header=None)
fidelities2 = fidelities2.applymap(lambda s: complex(s.replace('i', 'j'))).values
path = "../../experiments/tomography_walltoall_2/4/loss_values_qng_adam.csv"
loss_values2 = pd.read_csv(path, sep=",", header=None)
path = "../../experiments/tomography_walltoall_2/4/traces_qng_adam.csv"
traces2 = pd.read_csv(path, sep=",", header=None)

path = "../../experiments/tomography_walternating_2/4/fidelities_qng_adam.csv"
fidelities3 = pd.read_csv(path, sep=",", header=None)
fidelities3 = fidelities3.applymap(lambda s: complex(s.replace('i', 'j'))).values
path = "../../experiments/tomography_walternating_2/4/loss_values_qng_adam.csv"
loss_values3 = pd.read_csv(path, sep=",", header=None)
path = "../../experiments/tomography_walternating_2/4/traces_qng_adam.csv"
traces3 = pd.read_csv(path, sep=",", header=None)

plt.plot(fidelities1, label = 'W chain')
plt.plot(fidelities2, label = 'W alltoall')
plt.plot(fidelities3, label = 'W alternating')
plt.xlabel('Iteration')
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title('Fidelity')
plt.legend()
plt.show()
# Out:
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(traces1, label = 'W chain')
plt.plot(traces2, label = 'W alltoall')
plt.plot(traces3, label = 'W alternating')
plt.xlabel('Iteration')
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title('Trace')
plt.legend()
plt.show()

# %%
plt.plot(loss_values1, label = 'W chain')
plt.plot(loss_values2, label = 'W alltoall')
plt.plot(loss_values3, label = 'W alternating')
plt.xlabel('Iteration')
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title('Loss value')
plt.legend()
plt.show()

# %%
tracess = []

for i in range(1, 6):
    path = "../../experiments/tomography_walternating_" + str(i) + '/' + str(5) + '/traces_qng_adam.csv'
    traces = pd.read_csv(path, sep=",", header=None)
    plt.plot(traces, label = str(i) + ' layer')

plt.xlabel('Iteration')
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title('Traces')
plt.legend()
plt.show()

# %%
fidelities = []

for i in range(1, 6):
    path = "../../experiments/tomography_walternating_" + str(i) + '/' + str(3) + '/fidelities_qng_adam.csv'
    fidelitiess = pd.read_csv(path, sep=",", header=None)
    fidelitiess = fidelitiess.applymap(lambda s: complex(s.replace('i', 'j'))).values
    plt.plot(fidelitiess, label = str(i) + ' layer')

plt.xlabel('Iteration')
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title('Fidelitiess')
plt.legend()
plt.show()
# Out:
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
tracess = []
qubits = [3,4,5]
for j in qubits:
    for i in range(1, 6):
        path = "../../experiments/tomography_walltoall_" + str(i) + '/' + str(j) + '/traces.csv'

        traces = pd.read_csv(path, sep=",", header=None)
        # fidelities = fidelities.applymap(lambda s: complex(s.replace('i', 'j'))).values
        tracess.append(np.min(traces))
    plt.plot(range(1, 6), tracess, label = str(j) + ' qubits', marker = 'o')
    tracess = []

plt.xlabel('Number of layers')
plt.xticks(np.arange(1, 6, 1))
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title('Traces')
plt.legend()
plt.savefig('tomography_walltoall_.png', format='png', dpi=600)
plt.show()

# %%
fidelitiess = []
qubits = [3,4,5]
for j in qubits:
    for i in range(1, 6):
        path = "../../experiments/tomography_walternating_" + str(i) + '/' + str(j) + '/fidelities.csv'

        fidelities = pd.read_csv(path, sep=",", header=None)
        fidelities = fidelities.applymap(lambda s: complex(s.replace('i', 'j'))).values
        fidelitiess.append(np.max(fidelities))
    plt.plot(range(1, 6), fidelitiess, label = str(j) + ' qubits', marker = 'o')
    fidelitiess = []

plt.xlabel('Number of layers')
plt.xticks(np.arange(1, 6, 1))
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title('Fidelity')
plt.legend()
plt.savefig('tomography_walternating_.png', format='png', dpi=600)
plt.show()
