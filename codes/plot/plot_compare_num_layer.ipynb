# %%
import numpy as np
import matplotlib.pyplot as plt
import sys, os
import pandas as pd
sys.path.insert(1, '../../')
import qtm.visualize
# %load_ext autoreload
# %autoreload 2
# Out:
# <module 'qtm.visualize' from '..\\qtm\\visualize.py'>

# %% [markdown]
# ### Comparing between number of layers (QNG optimizer)

# %%
path = "../../experiments/linear_ansatz_15layer_sgd/"
dirs = os.listdir(path)
dirs = list(map(int, dirs))
dirs.sort()

# %%
fidelitiesghz, fidelitiesw, fidelitieshaar, tracesghz, tracesw, traceshaar = qtm.visualize.read_15layer(path, dirs)

# %%
qtm.visualize.plot_15layer('Fidelity', fidelitiesghz, fidelitiesw, fidelitieshaar, is_save=True)

# %%
qtm.visualize.plot_15layer('Trace', tracesghz, tracesw, traceshaar, is_save=True)

# %%
fidelitiesghz, fidelitiesw, fidelitieshaar, tracesghz, tracesw, traceshaar = qtm.visualize.read_15layer_last(path, dirs)

# %%
for dir in dirs:
    dir = str(dir)
    ghz = pd.read_csv(path + dir + "/loss_values_ghz.csv", sep=",", header=None)
    plt.plot(ghz, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %%
for dir in dirs:
    dir = str(dir)
    w = pd.read_csv(path + dir + "/loss_values_w.csv", sep=",", header=None)
    plt.plot(w, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %%
for dir in dirs:
    dir = str(dir)
    haar = pd.read_csv(path + dir + "/loss_values_haar.csv", sep=",", header=None)
    plt.plot(haar, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %% [markdown]
# ### Comparing between number of layers (Adam optimizer)

# %%
path = "../../experiments/linear_ansatz_15layer_adam/"
dirs = os.listdir(path)
dirs = list(map(int, dirs))
dirs.sort()

# %%
fidelitiesghz, fidelitiesw, fidelitieshaar, tracesghz, tracesw, traceshaar = qtm.visualize.read_15layer(path, dirs)

# %%
qtm.visualize.plot_15layer('Fidelity', fidelitiesghz, fidelitiesw, fidelitieshaar, is_save=True)

# %%
qtm.visualize.plot_15layer('Trace', tracesghz, tracesw, traceshaar, is_save=True)

# %%
for dir in dirs:
    dir = str(dir)
    ghz = pd.read_csv(path + dir + "/loss_values_ghz.csv", sep=",", header=None)
    plt.plot(ghz, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %%
for dir in dirs:
    dir = str(dir)
    w = pd.read_csv(path + dir + "/loss_values_w.csv", sep=",", header=None)
    plt.plot(w, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %%
for dir in dirs:
    dir = str(dir)
    haar = pd.read_csv(path + dir + "/loss_values_haar.csv", sep=",", header=None)
    plt.plot(haar, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %% [markdown]
# ### Comparing number of layer (QNG-Adam optimizer)

# %%
path = "../../experiments/linear_ansatz_15layer_qngadam/"
dirs = os.listdir(path)
dirs = list(map(int, dirs))
dirs.sort()

# %%
fidelitiesghz, fidelitiesw, fidelitieshaar, tracesghz, tracesw, traceshaar = qtm.visualize.read_15layer(path, dirs)

# %%
qtm.visualize.plot_15layer('Fidelity', fidelitiesghz, fidelitiesw, fidelitieshaar, is_save = True)

# %%
qtm.visualize.plot_15layer('Trace', tracesghz, tracesw, traceshaar, is_save=True)

# %%
for dir in dirs:
    dir = str(dir)
    ghz = pd.read_csv(path + dir + "/loss_values_ghz.csv", sep=",", header=None)
    plt.plot(ghz, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %%
for dir in dirs:
    dir = str(dir)
    w = pd.read_csv(path + dir + "/loss_values_w.csv", sep=",", header=None)
    plt.plot(w, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %%
for dir in dirs:
    dir = str(dir)
    haar = pd.read_csv(path + dir + "/loss_values_haar.csv", sep=",", header=None)
    plt.plot(haar, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()

# %% [markdown]
# ### Comparing number of layer (SGD optimizer)

# %%
path = "../../experiments/linear_ansatz_15layer_sgd/"
dirs = os.listdir(path)
dirs = list(map(int, dirs))
dirs.sort()

fidelitiesghz, fidelitiesw, fidelitieshaar, tracesghz, tracesw, traceshaar = qtm.visualize.read_15layer(path, dirs)
qtm.visualize.plot_15layer('Fidelity', fidelitiesghz, fidelitiesw, fidelitieshaar, is_save=True)

# %%
qtm.visualize.plot_15layer('Trace', tracesghz, tracesw, traceshaar, is_save=True)

# %%
for dir in dirs:
    dir = str(dir)
    ghz = pd.read_csv(path + dir + "/loss_values_w.csv", sep=",", header=None)
    plt.plot(ghz, label = dir + ' layer')
x = [1,2,3,4,5]
plt.title('Loss values')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend()
#plt.savefig('Compare_num_layer_GHZ.png', format='png', dpi=600)
plt.show()
