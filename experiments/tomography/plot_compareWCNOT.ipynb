# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
ansatz = 'wchain'
optimizer = 'qng'
qubits = [3,4,5]
for j in qubits:
    loss_fubini_studys = []
    for i in range(1, 6):
        if optimizer == 'sgd':
            path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/loss_values.csv'
        else:
            path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/loss_values_' + optimizer + '.csv'
        loss_values = pd.read_csv(path, sep=",", header=None).to_numpy()
        loss_fubini_study = np.sqrt(loss_values)
        loss_fubini_studys.append(np.min(loss_fubini_study))
    plt.plot(range(1, 6), loss_fubini_studys, label = str(j) + ' qubits', marker = 'o')

plt.xticks(np.arange(1, 6, 1), size = 16)
plt.yticks(np.arange(0, 1.2, 0.2), size = 16)
plt.xlabel('$L$', size = 16)
# plt.ylabel('Fubini-study distance', size = 16)
plt.legend(prop={'size': 16}, loc=1)
plt.savefig("./images/" + ansatz + '_' + optimizer + '.svg', format = 'svg', dpi = 1000)
plt.show()

# %%
ansatz = 'walltoall'
optimizer = 'qng'
color = ''
qubits = [3,4,5]
for j in qubits:
    if j == 3:
        color = '#1f77b4'
    if j == 4:
        color = '#ff7f0e'
    if j == 5:
        color = '#2ca02c'
    fidelitiess = []
    for i in range(1, 6):
        if optimizer == 'sgd':
            path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/fidelities.csv'
        else:
            path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/fidelities_' + optimizer + '.csv'
        fidelities = pd.read_csv(path, sep=",", header=None)
        fidelities = fidelities.applymap(lambda s: complex(s.replace('i', 'j'))).values
        fidelitiess.append(np.max(fidelities))
    plt.plot(range(1, 6), fidelitiess, label = str(j) + ' qubits', color = color, marker = 'o')
    fidelitiess = []
    for i in range(1, 6):
        if optimizer == 'sgd':
            path = "../../experiments/tomography/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/fidelities.csv'
        else:
            path = "../../experiments/tomography/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/fidelities_' + optimizer + '.csv'
        fidelities = pd.read_csv(path, sep=",", header=None)
        fidelities = fidelities.applymap(lambda s: complex(s.replace('i', 'j'))).values
        fidelitiess.append(np.max(fidelities))
    plt.plot(range(1, 6), fidelitiess, label = str(j) + ' qubits', color = color, linestyle='dashed', marker = 'o')

plt.xticks(np.arange(1, 6, 1), size = 16)
plt.yticks(np.arange(0, 1.2, 0.2), size = 16)
# plt.xlabel('$L$', size = 16) 
# plt.ylabel('Fidelity', size = 16)
plt.legend(prop={'size': 16}, loc=4)
plt.savefig("./imagesCNOT_fidelity/" + ansatz + '_' + optimizer + '.svg', format = 'svg', dpi = 1000)
plt.show()
# Out:
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
optimizer = 'qng'

j = 3
for ansatz in ['wchain', 'walternating', 'walltoall']:
    fidelitiess = []
    if ansatz == 'wchain':
        marker = 'o'
    if ansatz == 'walternating':
        marker = 's'
    if ansatz == 'walltoall':
        marker = '^'
    for i in range(1, 6):
        path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/fidelities_' + optimizer + '.csv'
        fidelities = pd.read_csv(path, sep=",", header=None)
        fidelities = fidelities.applymap(lambda s: complex(s.replace('i', 'j'))).values
        fidelitiess.append(np.max(fidelities))
    plt.plot(range(1, 6), fidelitiess, label = ansatz + ' CNOT', color = 'blue', marker = marker)
    fidelitiess = []
    for i in range(1, 6):
        path = "../../experiments/tomography/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/fidelities_' + optimizer + '.csv'
        fidelities = pd.read_csv(path, sep=",", header=None)
        fidelities = fidelities.applymap(lambda s: complex(s.replace('i', 'j'))).values
        fidelitiess.append(np.max(fidelities))
    plt.plot(range(1, 6), fidelitiess, label = ansatz, color = 'orange', linestyle='dashed', marker = marker)

plt.xticks(np.arange(1, 6, 1), size = 16)
plt.yticks(np.arange(0, 1.2, 0.2), size = 16)
# plt.xlabel('$L$', size = 16) 
# plt.ylabel('Fidelity', size = 16)
plt.legend(prop={'size': 16}, loc=4)
plt.savefig("./imagesCNOT_fidelity/sub-tomo.eps", format = 'eps', dpi = 1000)
plt.show()
# Out:
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\haime\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
tracess = []
ansatz = 'walternating'
for i in range(1, 6):
    path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(5) + '/loss_values_adam.csv'
    loss_values = pd.read_csv(path, sep=",", header=None)
    plt.plot(loss_values, label = str(i) + ' layer')

plt.xlabel('Iteration')
plt.yticks(np.arange(0, 1.4, 0.2))
plt.ylabel('Value')
plt.title(ansatz)
plt.legend()
plt.show()

# %% [markdown]
# ### Comparing Optimizer

# %%
i = 2
j = 3
ansatz = 'wchain'
path = "../../experiments/tomography/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/loss_values_adam.csv'
loss_values = pd.read_csv(path, sep=",", header=None).to_numpy()
loss_fubini_study = np.sqrt(loss_values)
plt.plot(loss_fubini_study, label = 'Adam')
path = "../../experiments/tomography/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/loss_values_qng.csv'
loss_values = pd.read_csv(path, sep=",", header=None).to_numpy()
loss_fubini_study = np.sqrt(loss_values)
plt.plot(loss_fubini_study, label = 'QNG')
path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/loss_values_adam.csv'
loss_values = pd.read_csv(path, sep=",", header=None).to_numpy()
loss_fubini_study = np.sqrt(loss_values)
plt.plot(loss_fubini_study, label = 'CNOT Adam')
path = "../../experiments/tomographyCNOT/tomography_" + ansatz + "_" + str(i) + '/' + str(j) + '/loss_values_qng.csv'
loss_values = pd.read_csv(path, sep=",", header=None).to_numpy()
loss_fubini_study = np.sqrt(loss_values)
plt.plot(loss_fubini_study, label = 'CNOT QNG')
plt.xlabel('Iteration')
plt.yticks(np.arange(0, 1.2, 0.2))
plt.ylabel('Fubini-study distance')
plt.title(ansatz)
plt.legend()
plt.show()
