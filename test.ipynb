# %%
from matplotlib import pyplot as plt

traces = [
    0.4096683020051751,
    0.38431205676510183,
    0.002850346488947897,
    0.003193658451849867,
    0.0036112762390973783
]

fideliies = [
    0.9122345544497849,
    0.9232032511993111,
    0.9999959377541949,
    0.9999949002598432,
    0.9999934793207043
]

plt.xlabel("n-layer")
plt.ylabel("Value")
plt.plot(traces)
plt.plot(fideliies)
